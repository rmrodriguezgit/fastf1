# %%
import requests
import pandas as pd
import json
from pandas import json_normalize

# %%
year = input('Temporada : ')
# Out:
# Temporada : 2022

# %%
url = "http://ergast.com/api/f1/"
query = "constructorStandings.json"
urlquery = url + str(year) + '/'+query
print(urlquery)
# Out:
# http://ergast.com/api/f1/2022/constructorStandings.json

# %%
response = requests.get(urlquery)
data = response.json()
constructors = data['MRData']['StandingsTable']['StandingsLists'][0] 
                           ['ConstructorStandings']
constructors
# Out:
# [{'position': '1',
#   'positionText': '1',
#   'points': '545',
#   'wins': '12',
#   'Constructor': {'constructorId': 'red_bull',
#    'url': 'http://en.wikipedia.org/wiki/Red_Bull_Racing',
#    'name': 'Red Bull',
#    'nationality': 'Austrian'}},
#  {'position': '2',
#   'positionText': '2',
#   'points': '406',
#   'wins': '4',
#   'Constructor': {'constructorId': 'ferrari',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_Ferrari',
#    'name': 'Ferrari',
#    'nationality': 'Italian'}},
#  {'position': '3',
#   'positionText': '3',
#   'points': '371',
#   'wins': '0',
#   'Constructor': {'constructorId': 'mercedes',
#    'url': 'http://en.wikipedia.org/wiki/Mercedes-Benz_in_Formula_One',
#    'name': 'Mercedes',
#    'nationality': 'German'}},
#  {'position': '4',
#   'positionText': '4',
#   'points': '125',
#   'wins': '0',
#   'Constructor': {'constructorId': 'alpine',
#    'url': 'http://en.wikipedia.org/wiki/Alpine_F1_Team',
#    'name': 'Alpine F1 Team',
#    'nationality': 'French'}},
#  {'position': '5',
#   'positionText': '5',
#   'points': '107',
#   'wins': '0',
#   'Constructor': {'constructorId': 'mclaren',
#    'url': 'http://en.wikipedia.org/wiki/McLaren',
#    'name': 'McLaren',
#    'nationality': 'British'}},
#  {'position': '6',
#   'positionText': '6',
#   'points': '52',
#   'wins': '0',
#   'Constructor': {'constructorId': 'alfa',
#    'url': 'http://en.wikipedia.org/wiki/Alfa_Romeo_in_Formula_One',
#    'name': 'Alfa Romeo',
#    'nationality': 'Swiss'}},
#  {'position': '7',
#   'positionText': '7',
#   'points': '34',
#   'wins': '0',
#   'Constructor': {'constructorId': 'haas',
#    'url': 'http://en.wikipedia.org/wiki/Haas_F1_Team',
#    'name': 'Haas F1 Team',
#    'nationality': 'American'}},
#  {'position': '8',
#   'positionText': '8',
#   'points': '33',
#   'wins': '0',
#   'Constructor': {'constructorId': 'alphatauri',
#    'url': 'http://en.wikipedia.org/wiki/Scuderia_AlphaTauri',
#    'name': 'AlphaTauri',
#    'nationality': 'Italian'}},
#  {'position': '9',
#   'positionText': '9',
#   'points': '25',
#   'wins': '0',
#   'Constructor': {'constructorId': 'aston_martin',
#    'url': 'http://en.wikipedia.org/wiki/Aston_Martin_in_Formula_One',
#    'name': 'Aston Martin',
#    'nationality': 'British'}},
#  {'position': '10',
#   'positionText': '10',
#   'points': '6',
#   'wins': '0',
#   'Constructor': {'constructorId': 'williams',
#    'url': 'http://en.wikipedia.org/wiki/Williams_Grand_Prix_Engineering',
#    'name': 'Williams',
#    'nationality': 'British'}}]

# %%
df = pd.DataFrame(constructors)
df
# Out:
#   position positionText points wins  \
# 0        1            1    545   12
# 1        2            2    406    4
# 2        3            3    371    0
# 3        4            4    125    0
# 4        5            5    107    0
# 5        6            6     52    0
# 6        7            7     34    0
# 7        8            8     33    0
# 8        9            9     25    0
# 9       10           10      6    0
#
#                                          Constructor
# 0  {'constructorId': 'red_bull', 'url': 'http://e...
# 1  {'constructorId': 'ferrari', 'url': 'http://en...
# 2  {'constructorId': 'mercedes', 'url': 'http://e...
# 3  {'constructorId': 'alpine', 'url': 'http://en....
# 4  {'constructorId': 'mclaren', 'url': 'http://en...
# 5  {'constructorId': 'alfa', 'url': 'http://en.wi...
# 6  {'constructorId': 'haas', 'url': 'http://en.wi...
# 7  {'constructorId': 'alphatauri', 'url': 'http:/...
# 8  {'constructorId': 'aston_martin', 'url': 'http...
# 9  {'constructorId': 'williams', 'url': 'http://e...

# %%
df2 = pd.json_normalize(constructors)
df2
# Out:
#   position positionText points wins Constructor.constructorId  \
# 0        1            1    545   12                  red_bull
# 1        2            2    406    4                   ferrari
# 2        3            3    371    0                  mercedes
# 3        4            4    125    0                    alpine
# 4        5            5    107    0                   mclaren
# 5        6            6     52    0                      alfa
# 6        7            7     34    0                      haas
# 7        8            8     33    0                alphatauri
# 8        9            9     25    0              aston_martin
# 9       10           10      6    0                  williams
#
#                                      Constructor.url Constructor.name  \
# 0       http://en.wikipedia.org/wiki/Red_Bull_Racing         Red Bull
# 1      http://en.wikipedia.org/wiki/Scuderia_Ferrari          Ferrari
# 2  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...         Mercedes
# 3        http://en.wikipedia.org/wiki/Alpine_F1_Team   Alpine F1 Team
# 4               http://en.wikipedia.org/wiki/McLaren          McLaren
# 5  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...       Alfa Romeo
# 6          http://en.wikipedia.org/wiki/Haas_F1_Team     Haas F1 Team
# 7   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri       AlphaTauri
# 8  http://en.wikipedia.org/wiki/Aston_Martin_in_F...     Aston Martin
# 9  http://en.wikipedia.org/wiki/Williams_Grand_Pr...         Williams
#
#   Constructor.nationality
# 0                Austrian
# 1                 Italian
# 2                  German
# 3                  French
# 4                 British
# 5                   Swiss
# 6                American
# 7                 Italian
# 8                 British
# 9                 British

# %%
df2.columns = ['posicion','posicionTexto','puntos','wins',
               'constructorId','url','escuderia','nacionalidad']
df2
# Out:
#   posicion posicionTexto puntos wins constructorId  \
# 0        1             1    545   12      red_bull
# 1        2             2    406    4       ferrari
# 2        3             3    371    0      mercedes
# 3        4             4    125    0        alpine
# 4        5             5    107    0       mclaren
# 5        6             6     52    0          alfa
# 6        7             7     34    0          haas
# 7        8             8     33    0    alphatauri
# 8        9             9     25    0  aston_martin
# 9       10            10      6    0      williams
#
#                                                  url       escuderia  \
# 0       http://en.wikipedia.org/wiki/Red_Bull_Racing        Red Bull
# 1      http://en.wikipedia.org/wiki/Scuderia_Ferrari         Ferrari
# 2  http://en.wikipedia.org/wiki/Mercedes-Benz_in_...        Mercedes
# 3        http://en.wikipedia.org/wiki/Alpine_F1_Team  Alpine F1 Team
# 4               http://en.wikipedia.org/wiki/McLaren         McLaren
# 5  http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...      Alfa Romeo
# 6          http://en.wikipedia.org/wiki/Haas_F1_Team    Haas F1 Team
# 7   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri      AlphaTauri
# 8  http://en.wikipedia.org/wiki/Aston_Martin_in_F...    Aston Martin
# 9  http://en.wikipedia.org/wiki/Williams_Grand_Pr...        Williams
#
#   nacionalidad
# 0     Austrian
# 1      Italian
# 2       German
# 3       French
# 4      British
# 5        Swiss
# 6     American
# 7      Italian
# 8      British
# 9      British

# %%
df2.dtypes
# Out:
# posicion         object
# posicionTexto    object
# puntos           object
# wins             object
# constructorId    object
# url              object
# escuderia        object
# nacionalidad     object
# dtype: object

# %%
df2['posicion'] = df2['posicion'].astype(int)
df2['puntos'] = df2['puntos'].astype(float)
df2['wins'] = df2['wins'].astype(int)

# %%
df2.describe()
# Out:
#        posicion      puntos       wins
# count  10.00000   10.000000  10.000000
# mean    5.50000  170.400000   1.600000
# std     3.02765  194.885836   3.864367
# min     1.00000    6.000000   0.000000
# 25%     3.25000   33.250000   0.000000
# 50%     5.50000   79.500000   0.000000
# 75%     7.75000  309.500000   0.000000
# max    10.00000  545.000000  12.000000
