# %%
import fastf1

import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib import cm
import numpy as np

# %%
fastf1.Cache.enable_cache('cache')

# %%
year = int(input('Año: '))
wknd = int(input('Round: '))
print('------ Session Type ------')
print('R - Race')
print('Q - Qualifying')
print('SQ - Sprint Qualifying')
print('FP1 - Practice 1')
print('FP2 - Practice 2')
print('FP3 - Practice 3')
print('--------------------------')
ses = input('Session :')
# Out:
# Año: 2022
# Round: 12
# ------ Session Type ------
# R - Race
# Q - Qualifying
# SQ - Sprint Qualifying
# FP1 - Practice 1
# FP2 - Practice 2
# FP3 - Practice 3
# --------------------------
# Session :FP1

# %%
session = fastf1.get_session(year, wknd, ses)
session.load()
# lap = session.laps.pick_fastest()
lap = session.laps.pick_quicklaps()
# Out:
# core           INFO 	Loading data for French Grand Prix - Practice 1 [v2.2.8]
# api            INFO 	Using cached data for driver_info
# core        WARNING 	Failed to load data from Ergast API! (This is expected for recent sessions)
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# api            INFO 	Using cached data for car_data
# api            INFO 	Using cached data for position_data
# api            INFO 	Using cached data for weather_data
# api            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '55', '47', '31', '24', '23', '22', '20', '19', '18', '16', '14', '11', '10', '6', '5', '4', '3', '63', '88']

# %%
#Si deseas escribir la salida
# with open('laps_pick_fastest.txt','w') as f:
#    f.write(f"{lap}")
lap
# Out:
#                       Time DriverNumber                LapTime  LapNumber  \
# 1   0 days 00:20:48.963000            1 0 days 00:01:35.727000          2
# 3   0 days 00:25:19.461000            1 0 days 00:01:34.991000          4
# 7   0 days 00:45:29.458000            1 0 days 00:01:34.346000          8
# 10  0 days 00:53:23.415000            1 0 days 00:01:34.021000         11
# 13  0 days 01:11:30.657000            1 0 days 00:01:37.909000         14
# ..                     ...          ...                    ...        ...
# 422 0 days 00:45:17.824000           88 0 days 00:01:37.800000          7
# 424 0 days 00:49:31.050000           88 0 days 00:01:37.843000          9
# 427 0 days 01:00:11.010000           88 0 days 00:01:36.439000         12
# 430 0 days 01:06:49.997000           88 0 days 00:01:36.332000         15
# 433 0 days 01:15:53.507000           88 0 days 00:01:40.062000         18
#
#      Stint PitOutTime PitInTime            Sector1Time            Sector2Time  \
# 1        1        NaT       NaT 0 days 00:00:24.368000 0 days 00:00:28.895000
# 3        1        NaT       NaT 0 days 00:00:24.043000 0 days 00:00:28.712000
# 7        2        NaT       NaT 0 days 00:00:23.570000 0 days 00:00:28.861000
# 10       3        NaT       NaT 0 days 00:00:23.468000 0 days 00:00:28.558000
# 13       4        NaT       NaT 0 days 00:00:24.836000 0 days 00:00:29.797000
# ..     ...        ...       ...                    ...                    ...
# 422      3        NaT       NaT 0 days 00:00:24.817000 0 days 00:00:29.979000
# 424      3        NaT       NaT 0 days 00:00:24.868000 0 days 00:00:29.836000
# 427      4        NaT       NaT 0 days 00:00:24.235000 0 days 00:00:29.548000
# 430      4        NaT       NaT 0 days 00:00:24.283000 0 days 00:00:29.556000
# 433      5        NaT       NaT 0 days 00:00:25.346000 0 days 00:00:30.500000
#
#                Sector3Time  ... IsPersonalBest Compound TyreLife  FreshTyre  \
# 1   0 days 00:00:42.464000  ...          False     SOFT      NaN       True
# 3   0 days 00:00:42.236000  ...          False     SOFT      NaN       True
# 7   0 days 00:00:41.915000  ...          False     SOFT      3.0       True
# 10  0 days 00:00:41.995000  ...           True     SOFT      6.0      False
# 13  0 days 00:00:43.276000  ...          False     SOFT      9.0      False
# ..                     ...  ...            ...      ...      ...        ...
# 422 0 days 00:00:43.004000  ...          False   MEDIUM      8.0      False
# 424 0 days 00:00:43.139000  ...          False   MEDIUM     10.0      False
# 427 0 days 00:00:42.656000  ...          False     SOFT      3.0       True
# 430 0 days 00:00:42.493000  ...           True     SOFT      6.0       True
# 433 0 days 00:00:44.216000  ...          False   MEDIUM     13.0      False
#
#               LapStartTime             Team  Driver  TrackStatus IsAccurate  \
# 1   0 days 00:19:13.236000  Red Bull Racing     VER            1       True
# 3   0 days 00:23:44.470000  Red Bull Racing     VER            1       True
# 7   0 days 00:43:55.112000  Red Bull Racing     VER            1       True
# 10  0 days 00:51:49.394000  Red Bull Racing     VER            2       True
# 13  0 days 01:09:52.748000  Red Bull Racing     VER            1       True
# ..                     ...              ...     ...          ...        ...
# 422 0 days 00:43:40.024000       Alfa Romeo     KUB            1       True
# 424 0 days 00:47:53.207000       Alfa Romeo     KUB            1       True
# 427 0 days 00:58:34.571000       Alfa Romeo     KUB            1       True
# 430 0 days 01:05:13.665000       Alfa Romeo     KUB            1       True
# 433 0 days 01:14:13.445000       Alfa Romeo     KUB            1       True
#
#                LapStartDate
# 1   2022-07-22 12:04:13.246
# 3   2022-07-22 12:08:44.480
# 7   2022-07-22 12:28:55.122
# 10  2022-07-22 12:36:49.404
# 13  2022-07-22 12:54:52.758
# ..                      ...
# 422 2022-07-22 12:28:40.034
# 424 2022-07-22 12:32:53.217
# 427 2022-07-22 12:43:34.581
# 430 2022-07-22 12:50:13.675
# 433 2022-07-22 12:59:13.455
#
# [156 rows x 27 columns]
